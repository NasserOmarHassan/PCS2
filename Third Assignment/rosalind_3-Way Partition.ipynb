# %%
def threepar(A):
    mi = []
    eq = []
    maj = []
    for e in A:
        if e < A[0]:
            mi.append(e)
        elif e == A[0]:
            eq.append(e)
        else:
            maj.append(e)
    mi.extend(eq)
    mi.extend(maj)
    print(*mi)

# %%
f = open('C:/Users/Nasser/Downloads/rosalind_par3.txt', 'r')
f = f.readlines()
n = int(f[0])
A = list(map(int, f[1].split()))
threepar(A)
# Out:
# -84680 -89477 -92481 -92783 -78960 -96103 -80958 -80032 -97264 -87001 -81080 -95788 -92466 -86525 -83760 -81037 -99578 -96444 -86583 -93034 -91406 -99227 -98429 -86091 -99342 -96261 -96432 -85220 -93618 -94739 -87779 -93967 -83609 -94104 -79485 -91163 -96005 -87214 -79803 -86605 -99033 -87048 -97676 -89898 -94107 -87255 -99832 -92364 -83906 -81544 -85972 -79666 -85343 -99843 -95268 -92630 -80239 -84800 -92119 -90358 -96054 -86698 -88619 -88444 -96565 -86140 -78424 -81036 -85100 -96336 -90098 -92502 -93503 -94362 -98562 -88407 -78946 -87447 -93022 -99183 -79298 -87511 -88861 -86131 -91487 -84918 -84692 -92467 -81876 -97427 -90276 -98838 -87310 -88463 -93892 -86481 -86988 -99245 -92537 -89055 -95822 -83617 -96883 -94676 -89193 -99433 -80160 -81023 -97430 -94493 -81342 -85363 -89077 -87811 -82951 -94148 -81954 -86936 -84062 -99784 -83659 -96168 -97415 -85917 -88481 -97495 -98508 -97707 -86317 -86724 -92344 -78573 -83298 -84396 -86973 -86517 -78374 -85914 -84631 -99172 -78688 -83097 -988
# ...
